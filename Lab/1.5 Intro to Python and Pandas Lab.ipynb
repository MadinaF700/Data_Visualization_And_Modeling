# %% [markdown]
# # Lab Instructions
#
# Find a dataset that interests you. I'd recommend starting on [Kaggle](https://www.kaggle.com/). Read through all of the material about the dataset and download a .CSV file.
#
# 1. Write a short summary of the data.  Where did it come from?  How was it collected?  What are the features in the data?  Why is this dataset interesting to you?
#
#    This dataset was published on Kaggle by Saad Ali Yaseen. It is part of an open educational data project available to the public for analysis. Unfortunately, the website does not clearly explain how the data was collected, but I assume it was gathered through student self-report surveys or school academic records. The dataset includes features such as study habits, sleep duration, attendance, past academic performance, and final exam scores. This dataset interests me because I am also a student, and it allows me to analyze which factors in students’ activities contribute to their success and apply those insights to myself.
#
# 2. Identify 5 interesting questions about your data that you can answer using Pandas methods.
#
#    a)Do students who study more hours tend to score higher        on the exam?
#    b)What is the average sleep duration of students who           scored above 40 on the exam?
#    c)Do students with higher attendance percentages tend to       score higher on the final exam?
#    d)What is the average of previous test scores among all        students?
#    e)What is the relationship between attendance and hours        studied?
#
#
# 4. Answer those questions!  You may use any method you want (including LLMs) to help you write your code; however, you should use Pandas to find the answers.  LLMs will not always write code in this way without specific instruction.
#
#
#
# 5. Write the answer to your question in a text box underneath the code you used to calculate the answer.

# %%
import pandas as pd
df = pd.read_csv("student_exam_scores.csv")
df.head()
# Out:
#   student_id  hours_studied  sleep_hours  attendance_percent  previous_scores  \
# 0       S001            8.0          8.8                72.1               45
# 1       S002            1.3          8.6                60.7               55
# 2       S003            4.0          8.2                73.7               86
# 3       S004            3.5          4.8                95.1               66
# 4       S005            9.1          6.4                89.8               71
#
#    exam_score
# 0        30.2
# 1        25.0
# 2        35.8
# 3        34.0
# 4        40.3

# %% [markdown]
# ## a)Do students who study more hours tend to score higher on the exam?

# %%
correlation = df['hours_studied'].corr(df['exam_score'])
print("Correlation between hours studied and exam score:", round(correlation, 2))
# Out:
# Correlation between hours studied and exam score: 0.78

# %% [markdown]
# Since the output number is close to 1, it means that students who studied more scored higher on the exam.

# %%
import matplotlib.pyplot as plt
x = df['hours_studied']
y = df['exam_score']

plt.scatter(x, y)
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
plt.title('Relationship Between Hours Studied and Exam Score')
plt.show()

# %% [markdown]
# The scatter plot shows a clear positive relationship between the number of hours studied and the exam score. This pattern suggests that students who dedicate more time to studying tend to perform better on exams.

# %% [markdown]
# ## b)What is the average sleep duration of students who scored above 40 on the exam?

# %%
avg_sleep = df[df['exam_score'] > 40]['sleep_hours'].mean()
print("Average sleep duration for students scoring above 40:", round(avg_sleep, 2))
# Out:
# Average sleep duration for students scoring above 40: 7.19

# %%
plt.scatter(df['sleep_hours'], df['exam_score'])
plt.xlabel('Sleep Hours')
plt.ylabel('Exam Score')
plt.title('Relationship Between Sleep Hours and Exam Score')
plt.show()

# %% [markdown]
# The scatter plot shows the relationship between sleep hours and exam scores. While there is no clear linear trend, students who scored above 40 tend to cluster around 5–6 hours and 8–9 hours of sleep. The average sleep duration for students scoring above 40 is approximately 7.19 hours.

# %% [markdown]
# ## c)Do students with higher attendance percentages tend to score higher on the final exam?

# %%
correlation = df['attendance_percent'].corr(df['exam_score'])
print("Correlation between attendance percentage and exam score:", round(correlation, 2))
# Out:
# Correlation between attendance percentage and exam score: 0.23

# %% [markdown]
# Since the output number is close to 0, it shows that students who attended more classes did not necessarily achieve higher scores than those who attended less.

# %%
plt.scatter(df['attendance_percent'], df['exam_score'])

plt.xlabel('Attendance Percentage')
plt.ylabel('Exam Score')
plt.title('Relationship Between Attendance and Exam Score')
plt.show()

# %% [markdown]
# The scatter plot confirms that there is no noticeable correlation between attendance percentage and exam scores. Students with both high and low attendance achieved similar results.

# %% [markdown]
# ## d)What is the average of previous test scores among all        students?

# %%
average_prev = df['previous_scores'].mean()
print("Average of previous test scores among all students:", round(average_prev, 2))
# Out:
# Average of previous test scores among all students: 66.8

# %%
df['previous_scores'].plot(kind='hist')
plt.xlabel('Previous Test Scores')
plt.ylabel('Number of Students')
plt.title('Distribution of Previous Test Scores')
plt.show()

# %% [markdown]
# The histogram shows that students’ previous test scores are lower near 65 and 80, with small peaks around 50 and 75. The average score appears to be approximately 66.

# %% [markdown]
#  ## e)What is the relationship between attendance and hours        studied?

# %%
correlation = df['attendance_percent'].corr(df['hours_studied'])
print("Correlation between attendance and hours studied:", round(correlation, 2))
# Out:
# Correlation between attendance and hours studied: -0.03

# %% [markdown]
# The correlation between attendance percentage and hours studied was approximately –0.03, indicating no significant relationship between the two variables. This suggests that attending more classes did not necessarily mean students spent more or less time studying outside of class.

# %%
plt.scatter(df['attendance_percent'], df['hours_studied'])
plt.xlabel('Attendance Percentage')
plt.ylabel('Hours Studied')
plt.title('Relationship Between Attendance and Hours Studied')
plt.show()
